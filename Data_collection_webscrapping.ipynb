# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# %%
url = "https://www.flipkart.com/search?q=refrigerator+double+door&otracker=AS_Query_HistoryAutoSuggest_2_0&otracker1=AS_Query_HistoryAutoSuggest_2_0&marketplace=FLIPKART&as-show=off&as=off&as-pos=2&as-type=HISTORY"

# %%
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
response.headers
# Out:
# {'server': 'nginx', 'date': 'Tue, 05 Aug 2025 10:41:33 GMT', 'content-type': 'text/html; charset=utf-8', 'transfer-encoding': 'chunked', 'content-security-policy': "script-src 'self' 'unsafe-eval' https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://dpm.demdex.net https://tnc.phonepe.com https://js-agent.newrelic.com https://bam.nr-data.net https://www.googletagmanager.com 'nonce-1482407902786924430'; style-src 'self' 'unsafe-inline' https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.net; img-src 'self' data: blob: https://*.flixcart.com https://*.flixcart.net https://images.ixigo.com https://flipkart.d1.sc.omtrdc.net https://www.facebook.com https://*.fkapi.net https://googleads.g.doubleclick.net https://www.google.com https://www.google.co.in https://www.googleadservices.com https://sp.analytics.yahoo.com https://bat.bing.com https://bat.r.msn.com https://pay.payzippy.com https://1.pay.payzippy.com https://tnc.phonepe.com https://im
# ...

# %%
html_code=response.text

# %%
html_code
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css"/> <meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/
# ...

# %%
url_1 =" https://www.flipkart.com/search?q=refrigerator+double+door&otracker=AS_Query_HistoryAutoSuggest_2_0&otracker1=AS_Query_HistoryAutoSuggest_2_0&marketplace=FLIPKART&as-show=off&as=off&as-pos=2&as-type=HISTORY"

# %%
request_header = {'Content-Type': 'application/json', 
                  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36',
                'Accept-Encoding': 'gzip, deflate, br, zstd'                  
                 }

response = requests.get(url_1, headers=request_header)

# %%
print(response.status_code)
# Out:
# 200

# %%
response.headers
# Out:
# {'server': 'nginx', 'date': 'Tue, 05 Aug 2025 10:41:35 GMT', 'content-type': 'text/html; charset=utf-8', 'transfer-encoding': 'chunked', 'content-security-policy': "script-src 'self' 'unsafe-eval' https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://dpm.demdex.net https://tnc.phonepe.com https://js-agent.newrelic.com https://bam.nr-data.net https://www.googletagmanager.com 'nonce-5959471768914993816'; style-src 'self' 'unsafe-inline' https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.net; img-src 'self' data: blob: https://*.flixcart.com https://*.flixcart.net https://images.ixigo.com https://flipkart.d1.sc.omtrdc.net https://www.facebook.com https://*.fkapi.net https://googleads.g.doubleclick.net https://www.google.com https://www.google.co.in https://www.googleadservices.com https://sp.analytics.yahoo.com https://bat.bing.com https://bat.r.msn.com https://pay.payzippy.com https://1.pay.payzippy.com https://tnc.phonepe.com https://im
# ...

# %%
response.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css"/> <meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/
# ...

# %%
response.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css"/> <meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"
# ...

# %%
html_data= response.text

# %%
html_data
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css"/> <meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/
# ...

# %%
BeautifulSoup
# Out:
# bs4.BeautifulSoup

# %%
soup = BeautifulSoup(html_data)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim2.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.066267.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %% [markdown]
# ## Product name and type

# %%
soup.title.text
# Out:
# 'Refrigerator Double Door- Buy Products Online at Best Price in India - All Categories | Flipkart.com'

# %%
product = soup.find("div",class_ = "KzDlHZ")

print(product.text)
# Out:
# Samsung 301 L Frost Free Double Door 3 Star Convertible Refrigerator

# %%
product_name = []

prod = soup.find_all("div",class_ = "KzDlHZ")

for i in prod:
    product_name.append(i.text)

# %%
product_name
# Out:
# ['Samsung 301 L Frost Free Double Door 3 Star Convertible Refrigerator',
#  'Samsung 350 L Frost Free Double Door 3 Star Convertible Refrigerator  with 5-in-1, Digital Inverter, W...',
#  'Samsung 236 L Frost Free Double Door 3 Star Convertible Refrigerator  with Digital Inverter and Displa...',
#  'Samsung 301 L Frost Free Double Door 3 Star Convertible Refrigerator  with Digital Inverter, Convertib...',
#  'LG 272 L Frost Free Double Door 3 Star Convertible Refrigerator  with Inverter Compressor, Express Fre...',
#  'Samsung 236 L Frost Free Double Door 3 Star Convertible Refrigerator  with Digital Inverter and Displa...',
#  'Samsung 236 L Frost Free Double Door 2 Star Refrigerator  with Digital Inverter',
#  'Whirlpool 235 L Frost Free Double Door 2 Star Refrigerator',
#  'Godrej 244 L Frost Free Double Door 4 Star Convertible Refrigerator  with 6-In-1 Convertible Freezer W...',
# ...

# %% [markdown]
# ## RATING OF THE PRODUCT

# %%
soup.find_all("div",class_="XQDdHH")
# Out:
# [<div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.4<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.2<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.4<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.2<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.2<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.5<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.3<img class="Rza2QY" src="..."/></div>,
#  <div class="XQDdHH">4.4<img class="Rza2QY" src="..."/></div>,
# ...

# %%
ratings= []
for rating in soup.find_all("div",class_="XQDdHH"):
    ratings.append(rating.text)

# %%
(ratings)
# Out:
# ['4.3',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.2',
#  '4.4',
#  '4.3',
#  '4.2',
#  '4.2',
#  '4.5',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.3',
#  '4.2',
#  '4.2',
#  '4.3',
#  '4.3',
#  '5',
#  '5',
#  '4.3',
#  '4',
#  '4',
#  '4.4',
#  '5',
#  '5',
#  '4.2',
#  '5',
#  '2',
#  '4.2',
#  '4',
#  '1']

# %%
import re
from bs4 import BeautifulSoup
import requests

# Sample soup creation (replace this with your actual Flipkart scraping soup object)
# Example: response = requests.get(url, headers=headers); soup = BeautifulSoup(response.content, 'html.parser')

# Prepare separate lists
inverter_list = []
stabilizer_list = []
warranty_list = []

# Define regex patterns
inverter_pattern =re.compile( r'\b(?:Smart|Digital|Normal|Reciprocating)\s+Inverter(?:\s+Compressor)?|\b(?:Normal|Reciprocating)\s+Compressor\b',
    re.IGNORECASE)
stabilizer_pattern = re.compile(r'\bBuilt[-\s]*in\s+Stabilizer\b', re.IGNORECASE)
warranty_pattern =re.compile(
    r'\b(?:\d+\+?\s*Years?\s*(?:on\s+\w+(?:\s+\w+)?(?:,)?\s*)?)+(?:from\s+\w+)?\b',
    re.IGNORECASE)


# Loop through each product block
for div in soup.find_all("div", class_="_6NESgJ"):
    text = div.get_text(separator=' ').strip()
    inverter = inverter_pattern.search(text)
    stabilizer = stabilizer_pattern.search(text)
    warranty = warranty_pattern.search(text)

    # Append to respective lists (use .group() only if match found)
    inverter_list.append(inverter.group().strip() if inverter else "")
    stabilizer_list.append(stabilizer.group().strip() if stabilizer else "")
    warranty_list.append(warranty.group().strip() if warranty else "")
    # Create separate lists
flat_list=[]
   # Loop through flat_list and sort each item into its category
for item in inverter_list:
        flat_list.append(item)
for item in stabilizer_list:
        flat_list.append(item)
for item in warranty_list:
        flat_list.append(item)
flat_list
# Out:
# ['Reciprocating Compressor',
#  'Reciprocating Compressor',
#  'Digital Inverter Compressor',
#  'Reciprocating Compressor',
#  'Smart Inverter Compressor',
#  'Digital Inverter Compressor',
#  'Digital Inverter Compressor',
#  'Reciprocating Compressor',
#  '',
#  'Smart Inverter Compressor',
#  'Reciprocating Compressor',
#  'Reciprocating Compressor',
#  '',
#  'Reciprocating Compressor',
#  'Smart Inverter',
#  'Smart Inverter Compressor',
#  'Reciprocating Compressor',
#  'Reciprocating Compressor',
#  'Reciprocating Compressor',
#  'Digital Inverter Compressor',
#  'Reciprocating Compressor',
#  '',
#  '',
#  'Digital Inverter Compressor',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
#  'Built-in Stabilizer',
# ...

# %%
print("stabilizer", stabilizer_list)
# Out:
# stabilizer ['Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer', 'Built-in Stabilizer']

# %%
print("inverter",inverter_list)
# Out:
# inverter ['Reciprocating Compressor', 'Reciprocating Compressor', 'Digital Inverter Compressor', 'Reciprocating Compressor', 'Smart Inverter Compressor', 'Digital Inverter Compressor', 'Digital Inverter Compressor', 'Reciprocating Compressor', '', 'Smart Inverter Compressor', 'Reciprocating Compressor', 'Reciprocating Compressor', '', 'Reciprocating Compressor', 'Smart Inverter', 'Smart Inverter Compressor', 'Reciprocating Compressor', 'Reciprocating Compressor', 'Reciprocating Compressor', 'Digital Inverter Compressor', 'Reciprocating Compressor', '', '', 'Digital Inverter Compressor']

# %%
print("capacity",warranty_list)
# Out:
# capacity ['1 Year', '1 Year', '1 year', '1 year', '1 Year', '1 year', '1 year', '1 Year', '1 Year', '1 Year', '1 Year', '1 Year', '1 Year', '1 Year', '1 Year on Product and 10 Years on Compressor from', '1 Year', '1 Year', '1 Year', '1 year', '1 year', '1 Year', '1 Year', '1 Year', '1 Year']

# %%
print("inverter",inverter_list)
print("stabilizer",stabilizer_list)
print("Warranty",warranty_list)
# Out:
# inverter ['Reciprocating Compressor', 'Reciprocating Compressor', 'Digital Inverter Compressor', 'Reciprocating Compressor', 'Smart Inverter Compressor', 'Digital Inverter Compressor', 'Digital Inverter Compressor', 'Reciprocating Compressor', '', 'Smart Inverter Compressor', 'Reciprocating Compressor', 'Reciprocating Compressor', '', 'Reciprocating Compressor', 'Smart Inverter', 'Smart Inverter Compressor', 'Reciprocating Compressor', 'Reciprocating Compressor', 'Reciprocating Compressor', 'Digital Inverter Compressor', 'Reciprocating Compressor', '', '', 'Digital Inverter Compressor']
# ...

# %%
price = soup.find_all("div",class_ = "Nx9bqj _4b5DiR")

# %%
prod_price = []
for i in price:
    prod_price.append(i.text)

# %%
prod_price
# Out:
# ['₹34,990',
#  '₹40,490',
#  '₹25,990',
#  '₹35,490',
#  '₹29,990',
#  '₹26,490',
#  '₹22,990',
#  '₹21,990',
#  '₹24,990',
#  '₹40,490',
#  '₹36,990',
#  '₹46,990',
#  '₹18,990',
#  '₹38,990',
#  '₹24,990',
#  '₹38,490',
#  '₹47,990',
#  '₹40,990',
#  '₹43,990',
#  '₹24,490',
#  '₹38,490',
#  '₹20,790',
#  '₹26,990',
#  '₹27,990']

# %%
print("product_name: ",len(product_name))
print("ratings_list: ",len(ratings))
print("inverter_list: ",len(inverter_list))
print("stabilizer_list: ",len(stabilizer_list))
print("warranty_list: ",len(warranty_list))
print("prod_price: ",len(prod_price))
# Out:
# product_name:  24
# ratings_list:  39
# inverter_list:  24
# stabilizer_list:  24
# warranty_list:  24
# prod_price:  24

# %%
ratings = ratings[:24]
df = pd.DataFrame({
    "product_name": product_name,
    "ratings": ratings,
    "inverter": inverter_list,
    "stabilizer": stabilizer_list,
    "Warranty": warranty_list,
    "prod_price":prod_price
})

# %%
df
# Out:
#                                          product_name ratings  \
# 0   Samsung 301 L Frost Free Double Door 3 Star Co...     4.3
# 1   Samsung 350 L Frost Free Double Door 3 Star Co...     4.3
# 2   Samsung 236 L Frost Free Double Door 3 Star Co...     4.4
# 3   Samsung 301 L Frost Free Double Door 3 Star Co...     4.3
# 4   LG 272 L Frost Free Double Door 3 Star Convert...     4.2
# 5   Samsung 236 L Frost Free Double Door 3 Star Co...     4.4
# 6   Samsung 236 L Frost Free Double Door 2 Star Re...     4.3
# 7   Whirlpool 235 L Frost Free Double Door 2 Star ...     4.2
# 8   Godrej 244 L Frost Free Double Door 4 Star Con...     4.2
# 9   LG 343 L Frost Free Double Door 3 Star Convert...     4.5
# 10  Samsung 330 L Frost Free Double Door 2 Star Co...     4.3
# 11  Samsung 396 L Frost Free Double Door 3 Star Co...     4.3
# 12  realme TechLife 233 L Frost Free Double Door 2...     4.3
# 13  Samsung 330 L Frost Free Double Door 3 Star Co...     4.3
# ...
